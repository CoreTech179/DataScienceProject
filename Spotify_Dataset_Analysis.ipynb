# %% [markdown]
# <a href="https://colab.research.google.com/github/CoreTech179/DataScienceProject/blob/main/Spotify_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #Uploading a CSV File with raw data

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-67621561-a6e9-488a-a9ca-4c98ca3bd9f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67621561-a6e9-488a-a9ca-4c98ca3bd9f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Read and showcase the CSV File using Pandas Module

# %%
songs = pd.read_csv("spotify_top_songs_audio_features.csv")
songs
# Out:
#                           id                         artist_names  \
# 0     000xQL6tZNLJzIrtIgxqSl                  ZAYN, PARTYNEXTDOOR
# 1     003eoIwxETJujVWmNFMoZy                         Alessia Cara
# 2     003vvx7Niy0yvhvHt4a68B                          The Killers
# 3     00B7TZ0Xawar6NZ00JFomN           Cardi B, Chance the Rapper
# 4     00Blm7zeNqgYLPtW6zg8cj              Post Malone, The Weeknd
# ...                      ...                                  ...
# 6508  7zgqtptZvhf8GEmdsM2vp2                         Taylor Swift
# 6509  7zjEyeBsaw9gV0jofJLfOM  Young Thug, A$AP Rocky, Post Malone
# 6510  7zl7kehxesNEo2pYkKXTSe          Eminem, Jack Harlow, Cordae
# 6511  7zvfDihYiJ8RQ1nRcpKBF5          Kendrick Lamar, Tanna Leone
# 6512  7zxRMhXxJMQCeDDg0rKAVo                      NAV, The Weeknd
#
#                                        track_name  \
# 0            Still Got Time (feat. PARTYNEXTDOOR)
# 1                                   Growing Pains
# ...

# %% [markdown]
# # Display Some portions of the data from this CSV

# %%
songs.head()
# Out:
#                        id                artist_names  \
# 0  000xQL6tZNLJzIrtIgxqSl         ZAYN, PARTYNEXTDOOR
# 1  003eoIwxETJujVWmNFMoZy                Alessia Cara
# 2  003vvx7Niy0yvhvHt4a68B                 The Killers
# 3  00B7TZ0Xawar6NZ00JFomN  Cardi B, Chance the Rapper
# 4  00Blm7zeNqgYLPtW6zg8cj     Post Malone, The Weeknd
#
#                              track_name              source    key   mode  \
# 0  Still Got Time (feat. PARTYNEXTDOOR)   RCA Records Label      G  Major
# 1                         Growing Pains  Def Jam Recordings  C#/Db  Minor
# 2                        Mr. Brightside      Island Records  C#/Db  Major
# 3   Best Life (feat. Chance The Rapper)        Atlantic/KSR      A  Major
# 4       One Right Now (with The Weeknd)    Republic Records  C#/Db  Major
#
#   time_signature  danceability  energy  speechiness  acousticness  \
# 0        4 beats         0.748   0.627       0.0639       0.13100
# ...

# %%
songs.describe()
# Out:
#        danceability       energy  speechiness  acousticness  instrumentalness  \
# count   6513.000000  6513.000000  6513.000000   6513.000000       6513.000000
# mean       0.681731     0.636522     0.121933      0.236761          0.012469
# std        0.141787     0.164813     0.113441      0.244784          0.075151
# min        0.150000     0.021800     0.023200      0.000008          0.000000
# 25%        0.591000     0.534000     0.044000      0.044400          0.000000
# 50%        0.698000     0.651000     0.072200      0.145000          0.000000
# 75%        0.785000     0.759000     0.163000      0.356000          0.000041
# max        0.985000     0.989000     0.966000      0.994000          0.953000
#
#           liveness      valence     loudness        tempo    duration_ms  \
# count  6513.000000  6513.000000  6513.000000  6513.000000    6513.000000
# mean      0.180168     0.492412    -6.350667   122.117244  202566.684170
# ...

# %% [markdown]
# # Getting the total no. of rows and Columns

# %%
songs.shape
# Out:
# (6513, 19)

# %% [markdown]
# #Frequency of Song Duration(in ms) on Spotify

# %%
songs['duration_ms'].value_counts()
# Out:
# 204347    6
# 198973    6
# 210200    5
# 247427    5
# 174253    5
#          ..
# 182093    1
# 174861    1
# 150619    1
# 216893    1
# 179773    1
# Name: duration_ms, Length: 5460, dtype: int64

# %%
songs['duration_ms'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #Getting the Top 5 most Songs on Spotify with Longest Duration

# %%
songs.loc[(songs['duration_ms']>=580000),'track_name']
# Out:
# 1931                                           Let's Go 4
# 2724    SWEET / I THOUGHT YOU WANTED TO DANCE (feat. B...
# 4745    All Too Well (10 Minute Version) (Taylor's Ver...
# 5847                                      Jesus Lord pt 2
# 6386                                   Poesia Acústica 13
# Name: track_name, dtype: object

# %% [markdown]
# **Jesus Lord pt 2 by Kanye West** is the longest duration song of Spotify over 69 thousand ms time play

# %%
songs.loc[(songs['duration_ms']>=690000),'artist_names']
# Out:
# 5847    Kanye West
# Name: artist_names, dtype: object

# %% [markdown]
# #Getting the top five most songs on Spotify with smallest durations

# %%
songs.loc[(songs['duration_ms']<=37000),'track_name']
# Out:
# 419                               Paul - Skit
# 1592                                   Get Up
# 1898    Juice WRLD Speaks From Heaven - Outro
# 3535                       Alfred - Interlude
# 4834                                    Intro
# Name: track_name, dtype: object

# %% [markdown]
# **Alfred - Interlude by Eminem** is the smallest duration song in Spotify lesser 30k ms

# %%
songs.loc[(songs['duration_ms']<=30500),'artist_names']
# Out:
# 3535    Eminem
# Name: artist_names, dtype: object

# %% [markdown]
# #Getting the frequency of similar name of the Tracks Listened on Spotify

# %%
songs['track_name'].value_counts()
# Out:
# Sleigh Ride          7
# Thunder              6
# Jingle Bell Rock     6
# Whatever It Takes    5
# Daylight             5
#                     ..
# Suge                 1
# Into It              1
# get him back!        1
# With you             1
# Some Way             1
# Name: track_name, Length: 5351, dtype: int64

# %%
songs['track_name'].value_counts()[:10].plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='track_name'>

# %% [markdown]
# #Geting the music Artist details with Most no. of  music tracks in Spotify

# %%
songs['artist_names'].value_counts()
# Out:
# Taylor Swift                     175
# Drake                            111
# BTS                               71
# Bad Bunny                         70
# Ariana Grande                     60
#                                 ...
# Becky G, NATTI NATASHA             1
# Shakira, Manuel Turizo             1
# Martin Garrix, Bono, The Edge      1
# Lauv, Julia Michaels               1
# Kendrick Lamar, Tanna Leone        1
# Name: artist_names, Length: 3001, dtype: int64

# %% [markdown]
# Spotify has 175 songs of Taylor Swift, 111 of Drake, 71 songs from bts, 70 songs from bad bunny and 60 songs from Ariana Grande. These are the most number of releases per artist in spotify

# %% [markdown]
# #Getting the Top 5 artist names with most no. of tracks on Spotify

# %%
songs['artist_names'].value_counts()[:5]
# Out:
# Taylor Swift     175
# Drake            111
# BTS               71
# Bad Bunny         70
# Ariana Grande     60
# Name: artist_names, dtype: int64

# %% [markdown]
# #The frequency of trending songs :

# %%
songs['weeks_on_chart'].value_counts()
# Out:
# 1      1805
# 2       718
# 3       428
# 4       309
# 5       291
#        ...
# 152       1
# 147       1
# 169       1
# 158       1
# 161       1
# Name: weeks_on_chart, Length: 159, dtype: int64

# %% [markdown]
# #The name of the songs which were on a trend or went viral for most number of times

# %%
songs.loc[(songs['weeks_on_chart']>=290),'track_name']
# Out:
# 688                 Believer
# 748                  Perfect
# 752     lovely (with Khalid)
# 4946    Say You Won't Let Go
# 6383            Shape of You
# Name: track_name, dtype: object

# %% [markdown]
# Believer is the most trending song of Spotify played over 365 weeks total. Perfect come second.Shape of you comes 3rd

# %%
songs.loc[(songs['weeks_on_chart']==367),'track_name']
# Out:
# 688    Believer
# Name: track_name, dtype: object

# %% [markdown]
# #Top five artists in Spotify who went viral most number of times

# %%
songs.loc[(songs['weeks_on_chart']>=291),'artist_names']
# Out:
# 688           Imagine Dragons
# 748                Ed Sheeran
# 752     Billie Eilish, Khalid
# 4946             James Arthur
# 6383               Ed Sheeran
# Name: artist_names, dtype: object

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(20,5))
sns.barplot(y="weeks_on_chart", x="artist_names", data=songs[songs['weeks_on_chart']>=200].sort_values('weeks_on_chart',ascending=False).head(11),color='green',alpha=0.7)
plt.xlabel("Trending time(in weeks)")
plt.ylabel("Artists")
plt.title("Trending artists in Spotify")
plt.show()

# %% [markdown]
# #Finding the most listened and the most unheard songs of Spotify

# %%
stm=songs.sort_values('streams')
stm.drop(['id'],axis=1).head(5)
# Out:
#           artist_names               track_name                        source  \
# 5968          J Balvin                     Bobo        Universal Music Mexico
# 3469          Maroon 5                    Sugar           Interscope Records*
# 968         Kanye West                   Famous  Rock The World/IDJ/Kanye LP7
# 1879  Kygo, Maty Noyes  Stay (feat. Maty Noyes)                          Kygo
# 4416         Nicky Jam        Hasta el Amanecer              Sony Music Latin
#
#         key   mode time_signature  danceability  energy  speechiness  \
# 5968  A#/Bb  Major        4 beats         0.729   0.888       0.1220
# 3469  C#/Db  Major        4 beats         0.748   0.788       0.0334
# 968   F#/Gb  Major        4 beats         0.465   0.735       0.1170
# 1879  G#/Ab  Major        4 beats         0.648   0.736       0.0385
# 4416  F#/Gb  Minor        4 beats         0.832   0.608       0.0385
#
#       acousticness  instrumentalness  liveness  valence  loudness    tempo  \
# ...

# %% [markdown]
# **J Balvin's Bobo , Sugar by maroon 5, Famous by Kenya W** are among the Top most among unheard songs list with over 2.5M streams

# %%
stm.drop(['id'],axis=1).tail(5)
# Out:
#        artist_names         track_name               source    key   mode  \
# 3523   Harry Styles          As It Was             Columbia  F#/Gb  Minor
# 748      Ed Sheeran            Perfect  Atlantic Records UK  G#/Ab  Major
# 6378  Lewis Capaldi  Someone You Loved       Vertigo Berlin  C#/Db  Major
# 6383     Ed Sheeran       Shape of You  Atlantic Records UK  C#/Db  Minor
# 435      The Weeknd    Blinding Lights     Republic Records  C#/Db  Major
#
#      time_signature  danceability  energy  speechiness  acousticness  \
# 3523        4 beats         0.520   0.731       0.0557       0.34200
# 748         3 beats         0.599   0.448       0.0232       0.16300
# 6378        4 beats         0.501   0.405       0.0319       0.75100
# 6383        4 beats         0.825   0.652       0.0802       0.58100
# 435         4 beats         0.514   0.730       0.0598       0.00146
#
#       instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# ...

# %% [markdown]
# **Blinding lights by the Weekend, Ed Sheeran's Shape of you and Someone You Loved by Lewis Capaldi** and among the most famous songs of Spotify With over 3B streams

# %% [markdown]
# #The top five production houses or producers in Spotify

# %%
stm['source'].value_counts()[:5]
# Out:
# Columbia                   317
# Republic Records           271
# Taylor Swift               178
# Warner Records             140
# Rimas Entertainment LLC    125
# Name: source, dtype: int64

# %%
stm['source'].value_counts()[:5].plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='source'>

# %% [markdown]
# #The best danceable songs or item songs in Spotify

# %%
stm.loc[(stm['danceability'] >=0.9)  , 'artist_names'].value_counts()
# Out:
# Migos                                             5
# Nicki Minaj                                       5
# Jack Harlow                                       5
# Lil Pump                                          5
# Superstar Pride                                   4
#                                                  ..
# Dua Lipa                                          1
# Young Thug, Young Stoner Life, Gunna, Lil Baby    1
# 347aidan                                          1
# Megan Thee Stallion, DaBaby                       1
# Bad Bunny, Chencho Corleone                       1
# Name: artist_names, Length: 192, dtype: int64

# %% [markdown]
# **Migos, Nicki Minaj, Jack Harlow and Lil pump** have the best danceable song collection in Spotify

# %%
stm.loc[(stm['danceability'] >=0.9)  , 'source'].value_counts()
# Out:
# Columbia                                         13
# Generation Now/Atlantic                          13
# Warner Records                                    9
# 300 Entertainment                                 9
# Republic Records                                  8
#                                                  ..
# A$AP Worldwide/Polo Grounds Music/RCA Records     1
# XO Records, LLC and Republic Records              1
# Epic/Legacy                                       1
# Republic Records - TXT                            1
# Bad Vibes Forever, LLC                            1
# Name: source, Length: 128, dtype: int64

# %%
sns.scatterplot(data=songs, x="danceability", y="streams",alpha=0.5,color="brown",edgecolor='green',hue='streams')
# Out:
# <Axes: xlabel='danceability', ylabel='streams'>

# %% [markdown]
# People usually like more number of danceable songs in Spotify. Highest number of streams are present in the danceability range of 0.6 to 0 .8

# %% [markdown]
# **Columbia, Generation Now/Atlantic and Warner recordes** are the best producers of Danceable songs in Spotify

# %%
songs.head(3)
# Out:
#                        id         artist_names  \
# 0  000xQL6tZNLJzIrtIgxqSl  ZAYN, PARTYNEXTDOOR
# 1  003eoIwxETJujVWmNFMoZy         Alessia Cara
# 2  003vvx7Niy0yvhvHt4a68B          The Killers
#
#                              track_name              source    key   mode  \
# 0  Still Got Time (feat. PARTYNEXTDOOR)   RCA Records Label      G  Major
# 1                         Growing Pains  Def Jam Recordings  C#/Db  Minor
# 2                        Mr. Brightside      Island Records  C#/Db  Major
#
#   time_signature  danceability  energy  speechiness  acousticness  \
# 0        4 beats         0.748   0.627       0.0639       0.13100
# 1        4 beats         0.353   0.755       0.7330       0.08220
# 2        4 beats         0.352   0.911       0.0747       0.00121
#
#    instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# 0               0.0    0.0852    0.524    -6.029  120.963       188491
# ...

# %% [markdown]
# #Deleting Unneccessary column name ID

# %%
stm = stm.drop('id',axis=1)

# %%
stm.head(3)
# Out:
#      artist_names track_name                        source    key   mode  \
# 5968     J Balvin       Bobo        Universal Music Mexico  A#/Bb  Major
# 3469     Maroon 5      Sugar           Interscope Records*  C#/Db  Major
# 968    Kanye West     Famous  Rock The World/IDJ/Kanye LP7  F#/Gb  Major
#
#      time_signature  danceability  energy  speechiness  acousticness  \
# 5968        4 beats         0.729   0.888       0.1220        0.1170
# 3469        4 beats         0.748   0.788       0.0334        0.0591
# 968         4 beats         0.465   0.735       0.1170        0.0711
#
#       instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# 5968          0.000016    0.1250    0.800    -2.864  177.908       209427
# 3469          0.000000    0.0863    0.884    -7.055  120.076       235493
# 968           0.000000    0.0975    0.409    -3.715  173.935       196040
#
#       weeks_on_chart  streams
# 5968               1  2525159
# 3469               1  2541963
# ...

# %% [markdown]
# #Here we have some Top 5 songs recommendations that those who like energetic songs they can listen to these songs
#
# #Energetic songs means it is often Loud, rhythmically active and gets the blood pumping.

# %%
stm.loc[(stm['energy']>=0.8),'track_name'][:5]
# Out:
# 5968                               Bobo
# 5122            Adventure of a Lifetime
# 4939      Sugar (feat. Francesco Yates)
# 2866    Shining (feat. Beyoncé & Jay-Z)
# 401                           Bad Blood
# Name: track_name, dtype: object

# %%
sns.scatterplot(data=songs, x="energy", y="streams",color="red",alpha=0.5,edgecolor="black",hue='energy')
# Out:
# <Axes: xlabel='energy', ylabel='streams'>

# %% [markdown]
# Energy or motivational songs are mostly liked as number of streams are directly proportional to the energy the song contains

# %% [markdown]
# #Getting the name of the most speechiness song with the name of the Artist on spotify

# %%
stm.loc[(stm['speechiness']>=0.8),'track_name'][:5]
# Out:
# 425                The Explanation
# 3033          Grandpa's Space Ship
# 4841    RNP (feat. Anderson .Paak)
# 3013             I Love You Dwayne
# 3551                          Skit
# Name: track_name, dtype: object

# %%
stm.loc[(stm['speechiness']>=0.8),'streams']
# Out:
# 425      3275927
# 3033     4248642
# 4841     4557573
# 3013     5553668
# 3551     8392247
# 419     17969356
# Name: streams, dtype: int64

# %% [markdown]
# All these streams are very close to X axis and their values mostly revolve around 0.0 x 1E9

# %%
sns.scatterplot(data=songs, x="speechiness", y="streams",hue='speechiness')
# Out:
# <Axes: xlabel='speechiness', ylabel='streams'>

# %% [markdown]
# The speechiness of the song and the number of streams the songs get are inversly proportional to each other. The less amount of Speechiness the amount number of streams is higher

# %% [markdown]
# #Getting the name of the most acousticness song with the name of the Artist on spotify

# %%
print(stm.loc[(stm['acousticness']>=0.994000),'track_name'])
print()
print(stm.loc[(stm['acousticness']>=0.994000),'artist_names'])
# Out:
# 4111    Carol of the Bells
# Name: track_name, dtype: object
#
# 4111    Mykola Dmytrovych Leontovych, John Williams
# Name: artist_names, dtype: object

# %%
sns.scatterplot(data=songs, x="acousticness", y="streams",color='yellow',edgecolor='brown',s=30)
# Out:
# <Axes: xlabel='acousticness', ylabel='streams'>

# %% [markdown]
# #Here we have some Top 5 songs recommendations that those who like more instrumental songs they can listen to these songs
#
# #Instrumentalness means how likely a song is to contains Vocals.
#
# #Generally songs with higher instrumentalness are less likely to have vocals

# %%
stm.loc[(stm['instrumentalness']>=0.8),'track_name'][:5]
# Out:
# 5037                 JACKBOYS
# 3577           Beautiful Trip
# 3737    Not My Responsibility
# 2690             Chromatica I
# 667             Chromatica II
# Name: track_name, dtype: object

# %%
sns.scatterplot(data=songs, x="instrumentalness", y="streams",hue='instrumentalness',edgecolor='black')
# Out:
# <Axes: xlabel='instrumentalness', ylabel='streams'>

# %% [markdown]
# From this we can conclude that lesser the amount of instrumentalness the more number of streams the song is getting

# %% [markdown]
# #The top melodious songs of Spotify are:

# %%
songs['tempo'].value_counts()
# Out:
# 100.021    5
# 110.001    5
# 140.057    5
# 100.003    5
# 124.080    5
#           ..
# 98.050     1
# 136.985    1
# 121.918    1
# 115.987    1
# 154.962    1
# Name: tempo, Length: 5353, dtype: int64

# %%
songs.describe()
# Out:
#        danceability       energy  speechiness  acousticness  instrumentalness  \
# count   6513.000000  6513.000000  6513.000000   6513.000000       6513.000000
# mean       0.681731     0.636522     0.121933      0.236761          0.012469
# std        0.141787     0.164813     0.113441      0.244784          0.075151
# min        0.150000     0.021800     0.023200      0.000008          0.000000
# 25%        0.591000     0.534000     0.044000      0.044400          0.000000
# 50%        0.698000     0.651000     0.072200      0.145000          0.000000
# 75%        0.785000     0.759000     0.163000      0.356000          0.000041
# max        0.985000     0.989000     0.966000      0.994000          0.953000
#
#           liveness      valence     loudness        tempo    duration_ms  \
# count  6513.000000  6513.000000  6513.000000  6513.000000    6513.000000
# mean      0.180168     0.492412    -6.350667   122.117244  202566.684170
# ...

# %% [markdown]
# The highest streamed songs with highest tempo value are :

# %% [markdown]
# #Here Tempo means the rate of speed in which a peice of music is played

# %%
stm.loc[(stm['tempo']>200) & (stm['streams']>500000000),'track_name'].value_counts()
# Out:
# Until I Found You                           1
# It's the Most Wonderful Time of the Year    1
# Last Night                                  1
# Name: track_name, dtype: int64

# %%
sns.scatterplot(data=songs, x="tempo", y="streams",edgecolor="black",hue='tempo')
# Out:
# <Axes: xlabel='tempo', ylabel='streams'>

# %% [markdown]
# Average tempo songs have got the most number of streams in Spotify

# %%
stm.sort_values('tempo').tail(5)
# Out:
#                           artist_names  \
# 3480          Taylor Swift, The Chicks
# 1059  Bing Crosby, The Andrews Sisters
# 4808                      Taylor Swift
# 616                      Sfera Ebbasta
# 5284            J Balvin, Jeon, Anitta
#
#                                              track_name  \
# 3480          Soon You’ll Get Better (feat. The Chicks)
# 1059                   Mele Kalikimaka - Single Version
# 4808  State Of Grace (Acoustic Version) (Taylor's Ve...
# 616                                     Ricchi x Sempre
# 5284                                            Machika
#
#                            source    key   mode time_signature  danceability  \
# 3480                 Taylor Swift      C  Major        4 beats         0.433
# 1059                       Geffen  D#/Eb  Major        4 beats         0.513
# 4808                 Taylor Swift      G  Major        3 beats         0.445
# ...

# %% [markdown]
#  **J Balvin, Jeon and Anitta's	*Machika*, Sfera Ebbasta's	*Ricchi x Sempre* and Taylor Swift's	*State Of Grace***  are the top melodious songs of Spotify. Out of this the song **Machika** is the most streamed(over 90M) and the most trending(14 weeks).

# %%
stm.loc[(stm['tempo']>207),'track_name']
# Out:
# 616                                       Ricchi x Sempre
# 4808    State Of Grace (Acoustic Version) (Taylor's Ve...
# 1059                     Mele Kalikimaka - Single Version
# 3480            Soon You’ll Get Better (feat. The Chicks)
# 5284                                              Machika
# Name: track_name, dtype: object

# %% [markdown]
# #Here in this plot we have observed that as the energy of the music increases the rate of danceability also increases exponentially

# %%
sns.scatterplot(x='energy',y='danceability',hue='danceability',data=stm,s=19)
# Out:
# <Axes: xlabel='energy', ylabel='danceability'>

# %% [markdown]
# #Here Valence represents how positive a song is
#
# # It ranges from 0 to 1
#
# #Songs with high Valence are more positive whereas songs with minimum Valence are more negative

# %%
stm.sort_values('valence').head(6)
# Out:
#                                           artist_names  \
# 690                             Billie Eilish, ROSALÍA
# 2380                              Shouse, David Guetta
# 2692  Eminem, KXNG Crooked, Royce Da 5'9", Joell Ortiz
# 3737                                     Billie Eilish
# 4276                                      Travis Scott
# 3135                                             Drake
#
#                                              track_name  \
# 690                     Lo Vas A Olvidar (with ROSALÍA)
# 2380             Love Tonight (David Guetta Remix Edit)
# 2692  I Will (feat. KXNG Crooked, Royce Da 5'9" & Jo...
# 3737                              Not My Responsibility
# 4276         The Plan - From the Motion Picture "TENET"
# 3135                                              Jaded
#
#                                   source    key   mode time_signature  \
# 690                             Columbia      E  Minor        4 beats
# ...

# %% [markdown]
# #Top 5 Positive Songs on Spotify

# %%
stm.loc[(stm['valence']>=0.9) & (stm['valence']<=1),'track_name'].value_counts()[:5]
# Out:
# Sunflower - Spider-Man: Into the Spider-Verse    5
# Cold Heart - PNAU Remix                          3
# Levitating (feat. DaBaby)                        3
# Merry Christmas Everyone                         3
# September                                        2
# Name: track_name, dtype: int64

# %%
sns.scatterplot(x='valence',y='streams',data=stm,color='brown',edgecolor='yellow',s=20)
# Out:
# <Axes: xlabel='valence', ylabel='streams'>

# %% [markdown]
# #Top 5 Negative Songs on Spotify

# %%
stm.loc[(stm['valence']>=0.030000),'track_name'].value_counts()[:5]
# Out:
# Sleigh Ride                 7
# Jingle Bell Rock            6
# Thunder                     6
# My Only Wish (This Year)    5
# Daylight                    5
# Name: track_name, dtype: int64

# %% [markdown]
# #Negative song with Top most week on the chart

# %%
stm.loc[(stm['valence']==0.032000) & (stm['weeks_on_chart']<=367.000000),'track_name'].value_counts()
# Out:
# Lo Vas A Olvidar (with ROSALÍA)    1
# Name: track_name, dtype: int64

# %% [markdown]
# #Posiive Song with Top most week on the chart

# %%
stm.loc[(stm['valence']==0.982000) & (stm['weeks_on_chart']<=367.000000),'track_name'].value_counts()
# Out:
# September    1
# Name: track_name, dtype: int64

# %%
stm.describe()
# Out:
#        danceability       energy  speechiness  acousticness  instrumentalness  \
# count   6513.000000  6513.000000  6513.000000   6513.000000       6513.000000
# mean       0.681731     0.636522     0.121933      0.236761          0.012469
# std        0.141787     0.164813     0.113441      0.244784          0.075151
# min        0.150000     0.021800     0.023200      0.000008          0.000000
# 25%        0.591000     0.534000     0.044000      0.044400          0.000000
# 50%        0.698000     0.651000     0.072200      0.145000          0.000000
# 75%        0.785000     0.759000     0.163000      0.356000          0.000041
# max        0.985000     0.989000     0.966000      0.994000          0.953000
#
#           liveness      valence     loudness        tempo    duration_ms  \
# count  6513.000000  6513.000000  6513.000000  6513.000000    6513.000000
# mean      0.180168     0.492412    -6.350667   122.117244  202566.684170
# ...

# %% [markdown]
# #To 5 Songs that performed live on the Stage maximum times

# %%
stm.loc[(stm['liveness']>=0.219) & (stm['liveness']<=0.977),'track_name'].value_counts()[:5]
# Out:
# Sleigh Ride              6
# God's Plan               4
# Lucid Dreams             4
# Roses - Imanbek Remix    4
# More Than You Know       4
# Name: track_name, dtype: int64

# %%
stm.head(3)
# Out:
#      artist_names track_name                        source    key   mode  \
# 5968     J Balvin       Bobo        Universal Music Mexico  A#/Bb  Major
# 3469     Maroon 5      Sugar           Interscope Records*  C#/Db  Major
# 968    Kanye West     Famous  Rock The World/IDJ/Kanye LP7  F#/Gb  Major
#
#      time_signature  danceability  energy  speechiness  acousticness  \
# 5968        4 beats         0.729   0.888       0.1220        0.1170
# 3469        4 beats         0.748   0.788       0.0334        0.0591
# 968         4 beats         0.465   0.735       0.1170        0.0711
#
#       instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# 5968          0.000016    0.1250    0.800    -2.864  177.908       209427
# 3469          0.000000    0.0863    0.884    -7.055  120.076       235493
# 968           0.000000    0.0975    0.409    -3.715  173.935       196040
#
#       weeks_on_chart  streams
# 5968               1  2525159
# 3469               1  2541963
# ...

# %% [markdown]
# # Spotify generally has songs of loudness level lesser than the reference level with most of them having a Duration between 100K to 300K milliseconds

# %%
sns.scatterplot(x='duration_ms',y='loudness',data=stm,hue='loudness')
# Out:
# <Axes: xlabel='duration_ms', ylabel='loudness'>

# %% [markdown]
# #From this plot we can observe that The more louder the music is the lesser Quality the music have while live performance

# %%
sns.scatterplot(x='liveness',y='loudness',data=stm,color='red',edgecolor='yellow')
# Out:
# <Axes: xlabel='liveness', ylabel='loudness'>
